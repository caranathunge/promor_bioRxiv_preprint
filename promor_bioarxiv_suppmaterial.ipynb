# %% [markdown]
# # bioRxiv preprint (August 2022)
#
# ## promor: a comprehensive R package for label-free proteomics data analysis and predictive modeling
#
# ### Supplementary Material

# %%
library(promor)
# Out:
# Warning message:
# “dependencies ‘pcaMethods’, ‘randomForest’ are not available”
# also installing the dependencies ‘Matrix’, ‘SparseM’, ‘MatrixModels’, ‘nloptr’, ‘zoo’, ‘tzdb’, ‘glue’, ‘prodlim’, ‘timechange’, ‘cli’, ‘pbkrtest’, ‘quantreg’, ‘lme4’, ‘lmtest’, ‘RcppEigen’, ‘clock’, ‘gower’, ‘hardhat’, ‘ipred’, ‘lubridate’, ‘vctrs’, ‘car’, ‘robustbase’, ‘sp’, ‘vcd’, ‘Rcpp’, ‘ranger’, ‘itertools’, ‘doRNG’, ‘ModelMetrics’, ‘recipes’, ‘gridExtra’, ‘VIM’, ‘missForest’, ‘caret’, ‘kernlab’, ‘xgboost’, ‘viridis’, ‘pROC’
#
#
# Warning message in install.packages("promor"):
# “installation of package ‘Matrix’ had non-zero exit status”
# Warning message in install.packages("promor"):
# “installation of package ‘nloptr’ had non-zero exit status”
# Warning message in install.packages("promor"):
# “installation of package ‘itertools’ had non-zero exit status”
# Warning message in install.packages("promor"):
# “installation of package ‘doRNG’ had non-zero exit status”
# ...

# %%
raw1 <- create_df(
  prot_groups = "https://raw.githubusercontent.com/caranathunge/promor_example_data/main/pg1.txt",
  exp_design = "https://raw.githubusercontent.com/caranathunge/promor_example_data/main/ed1.txt"
)
raw_filtered <- filterbygroup_na(raw1, set_na = 0.4)
# Out:
# Error in library(promor): there is no package called ‘promor’
# Traceback:
#
# 1. library(promor)

# %% [markdown]
# #### Supplementary Figure 1

# %%
heatmap_na(raw_filtered, palette = "magma", save = TRUE, reorder_y = TRUE,y_fun = mean, reorder_x = TRUE, x_fun = sum,
           file_path = "~/Google Drive/My Drive//EVMS_DigitalPatientProject/temp/", 
           plot_width = 3, plot_height = 6)
# Out:
# plot without title

# %%
imp_df_mp <- impute_na(raw_filtered, method = "minProb", seed = 327)

# %% [markdown]
# #### Supplementary Figure 2

# %%
impute_plot(original = raw_filtered, imputed = imp_df_mp, global = FALSE, 
            n_row = 3, n_col = 3, palette = "magma", save = TRUE,
            file_path = "~/Google Drive/My Drive//EVMS_DigitalPatientProject/temp/" , 
            plot_width = 6, plot_height = 3.5)
# Out:
# Warning message:
# “Removed 324 rows containing non-finite values (stat_density).”
# Warning message:
# “Removed 324 rows containing non-finite values (stat_density).”
# plot without title

# %%
norm_df <- normalize_data(imp_df_knn)

# %% [markdown]
# #### Supplementary Figure 3

# %%
norm_plot(original = imp_df_knn, normalized = norm_df, type = "density", palette = "magma",
          save = TRUE, file_path = "~/Google Drive/My Drive//EVMS_DigitalPatientProject/temp/" , 
          plot_width = 5, plot_height = 3.5)
# Out:
# plot without title

# %% [markdown]
# #### Supplementary Table 1

# %%
fit_df <- find_dep(norm_df, save_output = TRUE, file_path = "~/Google Drive/My Drive//EVMS_DigitalPatientProject/temp/" )
# Out:
# Warning message:
# “3 very small variances detected, have been offset away from zero”
# 1195 siginificantly differentially expressed proteins found.

# %% [markdown]
# #### Supplementary Figure 4

# %%
volcano_plot(fit_df,
             text_size = 6,
             palette = "magma",
             save = TRUE, file_path = "~/Google Drive/My Drive//EVMS_DigitalPatientProject/temp/" 
)
# Out:
# plot without title

# %% [markdown]
# #### Supplementary Figure 5

# %%
heatmap_de(fit_df = fit_df, norm_df = norm_df, palette = "magma",
           save = TRUE, file_path = "~/Google Drive/My Drive//EVMS_DigitalPatientProject/temp/" 
)
# Out:
# plot without title

# %%
raw2 <- create_df(
  prot_groups = "https://raw.githubusercontent.com/caranathunge/promor_example_data/main/pg2.txt",
  exp_design = "https://raw.githubusercontent.com/caranathunge/promor_example_data/main/ed2.txt",
  tech_reps = TRUE
)
# Out:
# 0 empty row(s) removed.
#
# 1 empty column(s) removed.
#
# 12 reverse protein(s) (rows) removed.
#
# 29 protein contaminant(s) (rows) removed.
#
# 188 protein(s) identified by 2 or fewer unique peptides removed.

# %% [markdown]
# #### Supplementary Figure 6

# %%
corr_plot(raw2, rep_1 = 1, rep_2 = 2, n_row = 3, n_col = 2, text_size = 12, palette = "magma",
         save = TRUE, file_path = "~/Google Drive/My Drive//EVMS_DigitalPatientProject/temp/")
# Out:
# Saving 7 x 7 in image
#
# Warning message:
# “Removed 285 rows containing missing values (geom_point).”
# Warning message:
# “Removed 285 rows containing missing values (geom_text).”
# Warning message:
# “Removed 302 rows containing missing values (geom_point).”
# Warning message:
# “Removed 302 rows containing missing values (geom_text).”
# Warning message:
# “Removed 259 rows containing missing values (geom_point).”
# Warning message:
# “Removed 259 rows containing missing values (geom_text).”
# Warning message:
# “Removed 352 rows containing missing values (geom_point).”
# Warning message:
# “Removed 352 rows containing missing values (geom_text).”
# Warning message:
# “Removed 249 rows containing missing values (geom_point).”
# Warning message:
# “Removed 249 rows containing missing values (geom_text).”
# Warning message:
# “Removed 303 rows containing missing values (geom_point).”
# Warning message:
# “Removed 303 rows containing missing values (geom_text).”

# %%
raw_ave <- aver_techreps(raw2)
raw_filtered <- filterbygroup_na(raw_ave, set_na = 0.40)
imp_df_svd <- impute_na(raw_filtered, method = "SVD", seed = 327)
norm_df <- normalize_data(imp_df_svd)
# Out:
# 197 proteins with higher than 40% NAs in at least one group removed.
# change in estimate:  0.002404697

# %% [markdown]
# #### Supplementary Table 2

# %%
fit_df <- find_dep(norm_df, save_output = TRUE, 
                   file_path = "~/Google Drive/My Drive//EVMS_DigitalPatientProject/temp/")
# Out:
# Warning message:
# “One very small variance detected, has been offset away from zero”
# 5 siginificantly differentially expressed proteins found.

# %% [markdown]
# #### Supplementary Figure 7

# %%
volcano_plot(fit_df, save = TRUE, palette = "magma", 
             file_path = "~/Google Drive/My Drive//EVMS_DigitalPatientProject/temp/")
# Out:
# plot without title

# %% [markdown]
# #### Supplementary Figure 8

# %%
covid_model_df <- pre_process(
  fit_df = covid_fit_df, 
  norm_df = covid_norm_df
)
feature_plot(
    model_df = covid_model_df,
    type = "density",
    n_row = 4,
    n_col = 2,
    save = TRUE, palette = "magma", 
    file_path = "~/Google Drive/My Drive//EVMS_DigitalPatientProject/temp/"
)
# Out:
# Total number of differentially expressed proteins (8) is less than n_top.
#
# None of the proteins show high pair-wise correlation.
#
#
#
# No highly correlated proteins to be removed.
#
# Using condition as id variables
# plot without title

# %% [markdown]
# #### Supplementary Figure 9

# %%
covid_split_df <- split_data(model_df = covid_model_df, seed = 8314)
covid_model_list <- train_models(split_df = covid_split_df, seed = 351)
performance_plot(
  model_list = covid_model_list,
  type = "dot",
    save = TRUE, palette = "magma", 
    file_path = "~/Google Drive/My Drive//EVMS_DigitalPatientProject/temp/"
)
# Out:
# Running svmRadial...
#
#
#
# Running rf...
#
#
#
# Running glm...
#
#
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: algorithm did not converge”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: algorithm did not converge”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: algorithm did not converge”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: algorithm did not converge”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: algorithm did not converge”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: algorithm did not converge”
# ...

# %% [markdown]
# #### Supplementary Figure 10

# %%
varimp_plot(
  model_list = covid_model_list,
  text_size = 7,
  n_row = 2,
  n_col = 2,
    save = TRUE, palette = "magma", 
    file_path = "~/Google Drive/My Drive//EVMS_DigitalPatientProject/temp/"
)
# Out:
# plot without title

# %% [markdown]
# #### Supplementary Figure 11

# %%
covid_prob_list <- test_models(
  model_list = covid_model_list,
  split_df = covid_split_df,
  type = "prob"
)
roc_plot(
  probability_list = covid_prob_list,
  split_df = covid_split_df,
    save = TRUE, palette = "magma", 
    file_path = "~/Google Drive/My Drive//EVMS_DigitalPatientProject/temp/"
)
# Out:
# Testing svmRadial...
#
#
#
# Testing rf...
#
#
#
# Testing glm...
#
#
#
# Testing xgbLinear...
#
#
#
# Done!
#
# Setting levels: control = Non.Severe, case = Severe
#
# Setting direction: controls > cases
#
# Setting levels: control = Non.Severe, case = Severe
#
# Setting direction: controls > cases
#
# Setting levels: control = Non.Severe, case = Severe
#
# Setting direction: controls > cases
#
# Setting levels: control = Non.Severe, case = Severe
#
# Setting direction: controls > cases
# plot without title
